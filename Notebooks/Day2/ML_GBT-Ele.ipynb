# %% [markdown]
# # Hands-on Day 2
#
# - course [slides](https://github.com/leggerf/MLCourse-2122/blob/master/Slides/Day2/Big%20data%20science%20-%20Day%202%20-%202122.pdf)
#
#
# # You'll learn
#
# ## ML methods
# - Gradient Boosting Trees with pyspark.ml
#
# ## ML techniques
# - hyperparameter optimisation
# - ROC curves

# %%
#initial imports
# %reload_ext custom_magics
# %load_ext autoreload
# %autoreload 2

# initial setup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Check out these custom functions
from custom_functions import *

# %%
num_workers=5
spark=%sc $num_workers

from pyspark.sql import SparkSession
spark_session = SparkSession(spark)

#check if spark is there
spark
# Out:
# <SparkContext master=k8s://https://192.168.2.39:6443 appName=jupyter-eleoracca>

# %% [markdown]
# # Data preprocessing

# %%
# read in input data

inputFile = 'hdfs://192.168.2.39/data/Higgs100k.parquet'
#inputFile = 'hdfs://192.168.2.39/data/Higgs1M.parquet'
#inputFile = 'hdfs://192.168.2.39/data/Higgs10M.parquet'

df = spark_session.read.format('parquet').option('header', 'true').option('inferschema', 'true').load(inputFile)

total_events = df.count()
print('There are '+str(total_events)+' events')
# Out:
# There are 99999 events

# %% [markdown]
# #  Exercise 1
#
# - split the dataframe *df* into two dataframes, called *train* and *test* containing respectively 80% and 20% of the events (randomly distributed between the two samples)

# %%
df.columns
# Out:
# ['label',
#  'lepton_pT',
#  'lepton_eta',
#  'lepton_phi',
#  'missing_energy_magnitude',
#  'missing_energy_phi',
#  'jet1_pt',
#  'jet1_eta',
#  'jet1_phi',
#  'jet1_b-tag',
#  'jet2_pt',
#  'jet2_eta',
#  'jet2_phi',
#  'jet2_b-tag',
#  'jet3_pt',
#  'jet3_eta',
#  'jet3_phi',
#  'jet3_b-tag',
#  'jet4_pt',
#  'je4_eta',
#  'jet4_phi',
#  'jet4_b-tag',
#  'm_jj',
#  'm_jjj',
#  'm_lv',
#  'm_jlv',
#  'm_bb',
#  'm_wbb',
#  'm_wwbb']

# %%
#split the dataset for training and test
test_size = 0.30

train, test = df.randomSplit([0.8, 0.2])

print('Events for training {}'.format(train.count()))
print('Events for validation {}'.format(test.count()))
# Out:
# Events for training 79975
# Events for validation 20024

# %% [markdown]
# #### Create the input feature vector - remember, this was part of yesterday hands-on (bonus)
#
# - Libraries for ML tipically take as inputs data in a very specific format. Documentation on how to do data preprocessing in Spark: https://spark.apache.org/docs/latest/ml-features.html
# - Try to add to the dataframe *train* a new column, called 'features' which is a vector column with all the variables above except for 'label'
#    - features = [lepton_pT, lepton_eta, lepton_phi, ...]
#    - Hint: look at the VectorAssembler transformer
# - do the same for dataframe *test*

# %%
feature = train.columns
feature.remove('label')

assembler = VectorAssembler(inputCols=feature, outputCol='features')
train = assembler.transform(train)

assembler = VectorAssembler(inputCols=feature, outputCol='features')
test = assembler.transform(test)

# %%
train.columns
# Out:
# ['label',
#  'lepton_pT',
#  'lepton_eta',
#  'lepton_phi',
#  'missing_energy_magnitude',
#  'missing_energy_phi',
#  'jet1_pt',
#  'jet1_eta',
#  'jet1_phi',
#  'jet1_b-tag',
#  'jet2_pt',
#  'jet2_eta',
#  'jet2_phi',
#  'jet2_b-tag',
#  'jet3_pt',
#  'jet3_eta',
#  'jet3_phi',
#  'jet3_b-tag',
#  'jet4_pt',
#  'je4_eta',
#  'jet4_phi',
#  'jet4_b-tag',
#  'm_jj',
#  'm_jjj',
#  'm_lv',
#  'm_jlv',
#  'm_bb',
#  'm_wbb',
#  'm_wwbb',
#  'features']

# %% [markdown]
# # ML models: GBT

# %%
# ML model: GBT (Gradient Boosting Trees)
# Documentation at https://spark.apache.org/docs/2.2.0/ml-classification-regression.html
from pyspark.ml.classification import GBTClassifier

# fast, about 1m to train
gbt = GBTClassifier(labelCol='label', featuresCol='features', maxIter=10, maxDepth=3)

# %%
# %%time
gbt_model = gbt.fit(train)
# Out:
# CPU times: user 16.1 ms, sys: 8.17 ms, total: 24.3 ms
# Wall time: 14.9 s

# %%
# compute AUC on the test set
result = gbt_model.transform(test)

from pyspark.ml.evaluation import BinaryClassificationEvaluator
evaluator = BinaryClassificationEvaluator(labelCol='label', metricName="areaUnderROC")
print("Test set AUC = " + str(evaluator.evaluate(result)))
# Out:
# Test set AUC = 0.7407867810676618

# %%
#print metrics
printMetrics(evaluator, result)
# Out:
# AUC: 0.741
# +-----+----------+-----+
# |label|prediction|count|
# +-----+----------+-----+
# |  1.0|       1.0| 7347|
# |  0.0|       1.0| 3319|
# |  1.0|       0.0| 3216|
# |  0.0|       0.0| 6142|
# +-----+----------+-----+
#
# n precision: 0.689
# n recall: 0.696
# n accuracy: 0.674
# n F1 score: 0.692

# %%
gbt_model.extractParamMap()
# Out:
# {Param(parent='GBTClassifier_09c6235ab439', name='cacheNodeIds', doc='If false, the algorithm will pass trees to executors to match instances with nodes. If true, the algorithm will cache node IDs for each instance. Caching can speed up training of deeper trees. Users can set how often should the cache be checkpointed or disable it by setting checkpointInterval.'): False,
#  Param(parent='GBTClassifier_09c6235ab439', name='checkpointInterval', doc='set checkpoint interval (>= 1) or disable checkpoint (-1). E.g. 10 means that the cache will get checkpointed every 10 iterations. Note: this setting will be ignored if the checkpoint directory is not set in the SparkContext.'): 10,
#  Param(parent='GBTClassifier_09c6235ab439', name='featureSubsetStrategy', doc="The number of features to consider for splits at each tree node. Supported options: 'auto' (choose automatically for task: If numTrees == 1, set to 'all'. If numTrees > 1 (forest), set to 'sqrt' for classification and to 'onethird' for regression), 'all' (use all features), 'onethird' (use 1/3 of the features), 'sqrt' (use sqrt(number of features)), 'log2' (use log2(number of features)), 'n' (when n is in the range (0, 1.0], use n * number of features. When n is in the range (1, number of features), use n features). default = 'auto'"): 'all',
#  Param(parent='GBTClassifier_09c6235ab439', name='featuresCol', doc='features column name.'): 'features',
#  Param(parent='GBTClassifier_09c6235ab439', name='impurity', doc='Criterion used for information gain calculation (case-insensitive). Supported options: variance'): 'variance',
#  Param(parent='GBTClassifier_09c6235ab439', name='labelCol', doc='label column name.'): 'label',
#  Param(parent='GBTClassifier_09c6235ab439', name='leafCol', doc='Leaf indices column name. Predicted leaf index of each instance in each tree by preorder.'): '',
#  Param(parent='GBTClassifier_09c6235ab439', name='lossType', doc='Loss function which GBT tries to minimize (case-insensitive). Supported options: logistic'): 'logistic',
#  Param(parent='GBTClassifier_09c6235ab439', name='maxBins', doc='Max number of bins for discretizing continuous features.  Must be >=2 and >= number of categories for any categorical feature.'): 32,
#  Param(parent='GBTClassifier_09c6235ab439', name='maxDepth', doc='Maximum depth of the tree. (>= 0) E.g., depth 0 means 1 leaf node; depth 1 means 1 internal node + 2 leaf nodes.'): 3,
#  Param(parent='GBTClassifier_09c6235ab439', name='maxIter', doc='max number of iterations (>= 0).'): 10,
#  Param(parent='GBTClassifier_09c6235ab439', name='maxMemoryInMB', doc='Maximum memory in MB allocated to histogram aggregation. If too small, then 1 node will be split per iteration, and its aggregates may exceed this size.'): 256,
#  Param(parent='GBTClassifier_09c6235ab439', name='minInfoGain', doc='Minimum information gain for a split to be considered at a tree node.'): 0.0,
#  Param(parent='GBTClassifier_09c6235ab439', name='minInstancesPerNode', doc='Minimum number of instances each child must have after split. If a split causes the left or right child to have fewer than minInstancesPerNode, the split will be discarded as invalid. Should be >= 1.'): 1,
#  Param(parent='GBTClassifier_09c6235ab439', name='minWeightFractionPerNode', doc='Minimum fraction of the weighted sample count that each child must have after split. If a split causes the fraction of the total weight in the left or right child to be less than minWeightFractionPerNode, the split will be discarded as invalid. Should be in interval [0.0, 0.5).'): 0.0,
#  Param(parent='GBTClassifier_09c6235ab439', name='predictionCol', doc='prediction column name.'): 'prediction',
#  Param(parent='GBTClassifier_09c6235ab439', name='probabilityCol', doc='Column name for predicted class conditional probabilities. Note: Not all models output well-calibrated probability estimates! These probabilities should be treated as confidences, not precise probabilities.'): 'probability',
#  Param(parent='GBTClassifier_09c6235ab439', name='rawPredictionCol', doc='raw prediction (a.k.a. confidence) column name.'): 'rawPrediction',
#  Param(parent='GBTClassifier_09c6235ab439', name='seed', doc='random seed.'): -2521213964090760811,
#  Param(parent='GBTClassifier_09c6235ab439', name='stepSize', doc='Step size (a.k.a. learning rate) in interval (0, 1] for shrinking the contribution of each estimator.'): 0.1,
#  Param(parent='GBTClassifier_09c6235ab439', name='subsamplingRate', doc='Fraction of the training data used for learning each decision tree, in range (0, 1].'): 1.0,
#  Param(parent='GBTClassifier_09c6235ab439', name='validationTol', doc='Threshold for stopping early when fit with validation is used. If the error rate on the validation input changes by less than the validationTol, then learning will stop early (before `maxIter`). This parameter is ignored when fit without validation is used.'): 0.01}

# %%
#make ROC curve
drawROC(result)

# %%
#plot features vs importance
drawFeatures(feature, gbt_model)

# %%
#plot signal vs background with prediction
plotSignalvsBgWithPrediction(test, result, 'm_bb')

# %% [markdown]
# # Exercise 2
#
# - try to change the hyperparameters of the GBT model (maxIter=50, maxDepth=10), and check what changes in terms of performances, feature importance, signal versus background separation. Be careful of training time if you increase them too much!

# %%
gbt = GBTClassifier(labelCol='label', featuresCol='features', maxIter=50, maxDepth=10)

# %%
# %%time
gbt_model = gbt.fit(train)
# Out:
# CPU times: user 39.2 ms, sys: 27.9 ms, total: 67.1 ms
# Wall time: 3min 23s

# %%
result = gbt_model.transform(test)
evaluator = BinaryClassificationEvaluator(labelCol='label', metricName="areaUnderROC")
print("Test set AUC = " + str(evaluator.evaluate(result)))
# Out:
# Test set AUC = 0.7823490202177599

# %%
printMetrics(evaluator, result)

drawROC(result)

drawFeatures(feature, gbt_model)

plotSignalvsBgWithPrediction(test, result, 'm_bb')
# Out:
# AUC: 0.782
# +-----+----------+-----+
# |label|prediction|count|
# +-----+----------+-----+
# |  1.0|       1.0| 7726|
# |  0.0|       1.0| 2989|
# |  1.0|       0.0| 2837|
# |  0.0|       0.0| 6472|
# +-----+----------+-----+
#
# n precision: 0.721
# n recall: 0.731
# n accuracy: 0.709
# n F1 score: 0.726

# %% [markdown]
# # Hyperparameter scan
#
# - documentation: https://spark.apache.org/docs/latest/ml-tuning.html

# %%
#reduce number of events for training if needed
subSample = train.sample(fraction=1.0/10, withReplacement=False).cache()
print('We will use ' +str(subSample.count()) + ' events for the grid search')
# Out:
# We will use 8071 events for the grid search

# %%
#Do hyperparameter tuning 
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator, TrainValidationSplit
from pyspark.ml.evaluation import BinaryClassificationEvaluator

gbt = GBTClassifier(labelCol='label', featuresCol='features', maxIter=10, maxDepth=3)

evaluator=BinaryClassificationEvaluator(metricName='areaUnderROC')

#choose hyperparameter space
paramGrid = ParamGridBuilder()\
  .addGrid(gbt.maxDepth, [1,5])\
  .addGrid(gbt.maxIter, [10,20])\
  .build()

# %%
# Train Validation Split (takes 1-2 minutes)
tvs = TrainValidationSplit(estimator=gbt,
                           estimatorParamMaps=paramGrid,
                           evaluator=evaluator,
                           trainRatio=0.8)# 80% of the data will be used for training, 20% for validation

# %% [markdown]
# **TIP:** after starting the following cell, close the Spark monitoring window or it will slow down your notebook display considerably.

# %%
#take care, might take long time, 
# %time bestModel = tvs.fit(subSample)
# Out:
# CPU times: user 259 ms, sys: 90.7 ms, total: 350 ms
# Wall time: 43.4 s

# %%
#It is possile to see the score obtained (in this case the AUC) for each set of parameters
#zip(bestModel.avgMetrics, paramGrid)

print('maxDepth = '+str(bestModel.bestModel._java_obj.getMaxDepth()))
print('maxIter = '+str(bestModel.bestModel._java_obj.getMaxIter()))
# Out:
# maxDepth = 5
# maxIter = 20

# %%
# compute accuracy on the test set
result = bestModel.transform(test)

evaluator = BinaryClassificationEvaluator(labelCol='label', metricName="areaUnderROC")
print("Test set AUC = " + str(evaluator.evaluate(result)))
# Out:
# Test set AUC = 0.7611316062833994

# %%
#make ROC curve with best model
drawROC(result)

# %%
#plot signal vs background with prediction
plotSignalvsBgWithPrediction(test, result, 'm_bb')

# %% [markdown]
# # Exercise 3
#
# - try implementing the cross validation method, and describe what changes (results, training time, performances, ...): do you get the same hyper-parameters?

# %%
tvs = TrainValidationSplit(estimator=gbt, estimatorParamMaps=paramGrid, evaluator=evaluator, trainRatio=0.8)

# %%
# %time bestModel = tvs.fit(subSample)
# Out:
# CPU times: user 231 ms, sys: 83.5 ms, total: 314 ms
# Wall time: 44.2 s

# %%
print('maxDepth = '+str(bestModel.bestModel._java_obj.getMaxDepth()))
print('maxIter = '+str(bestModel.bestModel._java_obj.getMaxIter()))
# Out:
# maxDepth = 5
# maxIter = 20

# %%
result = bestModel.transform(test)

evaluator = BinaryClassificationEvaluator(labelCol='label', metricName="areaUnderROC")
print("Test set AUC = " + str(evaluator.evaluate(result)))
# Out:
# Test set AUC = 0.7611585183609962

# %%
printMetrics(evaluator, result)

drawROC(result)

drawFeatures(feature, gbt_model)

plotSignalvsBgWithPrediction(test, result, 'm_bb')
# Out:
# AUC: 0.761
# +-----+----------+-----+
# |label|prediction|count|
# +-----+----------+-----+
# |  1.0|       1.0| 7268|
# |  0.0|       1.0| 2874|
# |  1.0|       0.0| 3295|
# |  0.0|       0.0| 6587|
# +-----+----------+-----+
#
# n precision: 0.717
# n recall: 0.688
# n accuracy: 0.692
# n F1 score: 0.702

# %%
#when you're done, stop spark, this will release the resources you're using
spark.stop()
